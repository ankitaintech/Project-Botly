# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
import os
from config import GOOGLE_API_KEY


# Set the API key
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
#Function to list available models
def list_available_models():
    models= genai.list_models()
    for model in models:
        print ("===========================================================================")
        print (f"Model Name: {model.name}, \n Description: {getattr(model, 'description', 'No description available')}")
        print ("===========================================================================")

#Call function to list model
list_available_models()
# Out:
# ===========================================================================
# Model Name: models/embedding-gecko-001,
#  Description: Obtain a distributed representation of a text.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.0-pro-vision-latest,
#  Description: The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-pro-vision,
#  Description: The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-pro-latest,
#  Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-pro-002,
#  Description: Stable version of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens, released in September of 2024.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-pro,
#  Description: Stable version of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens, released in May of 2024.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-flash-latest,
#  Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-flash,
#  Description: Alias that points to the most recent stable version of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-flash-002,
#  Description: Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in September of 2024.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-flash-8b,
#  Description: Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, released in October of 2024.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-flash-8b-001,
#  Description: Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, released in October of 2024.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-1.5-flash-8b-latest,
#  Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, released in October of 2024.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-pro-exp-03-25,
#  Description: Experimental release (March 25th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-pro-preview-03-25,
#  Description: Gemini 2.5 Pro Preview 03-25
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-preview-04-17,
#  Description: Preview release (April 17th, 2025) of Gemini 2.5 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-preview-05-20,
#  Description: Preview release (April 17th, 2025) of Gemini 2.5 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash,
#  Description: Stable version of Gemini 2.5 Flash, our mid-size multimodal model that supports up to 1 million tokens, released in June of 2025.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-preview-04-17-thinking,
#  Description: Preview release (April 17th, 2025) of Gemini 2.5 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-lite-preview-06-17,
#  Description: Preview release (June 11th, 2025) of Gemini 2.5 Flash Lite
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-pro-preview-05-06,
#  Description: Preview release (May 6th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-pro-preview-06-05,
#  Description: Preview release (June 5th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-pro,
#  Description: Stable release (June 17th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-exp,
#  Description: Gemini 2.0 Flash Experimental
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash,
#  Description: Gemini 2.0 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-001,
#  Description: Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in January of 2025.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-exp-image-generation,
#  Description: Gemini 2.0 Flash (Image Generation) Experimental
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-lite-001,
#  Description: Stable version of Gemini 2.0 Flash Lite
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-lite,
#  Description: Gemini 2.0 Flash-Lite
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-preview-image-generation,
#  Description: Gemini 2.0 Flash Preview Image Generation
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-lite-preview-02-05,
#  Description: Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-lite-preview,
#  Description: Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-pro-exp,
#  Description: Experimental release (March 25th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-pro-exp-02-05,
#  Description: Experimental release (March 25th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-exp-1206,
#  Description: Experimental release (March 25th, 2025) of Gemini 2.5 Pro
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-thinking-exp-01-21,
#  Description: Preview release (April 17th, 2025) of Gemini 2.5 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-thinking-exp,
#  Description: Preview release (April 17th, 2025) of Gemini 2.5 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-thinking-exp-1219,
#  Description: Preview release (April 17th, 2025) of Gemini 2.5 Flash
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-preview-tts,
#  Description: Gemini 2.5 Flash Preview TTS
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-pro-preview-tts,
#  Description: Gemini 2.5 Pro Preview TTS
# ===========================================================================
# ===========================================================================
# Model Name: models/learnlm-2.0-flash-experimental,
#  Description: LearnLM 2.0 Flash Experimental
# ===========================================================================
# ===========================================================================
# Model Name: models/gemma-3-1b-it,
#  Description:
# ===========================================================================
# ===========================================================================
# Model Name: models/gemma-3-4b-it,
#  Description:
# ===========================================================================
# ===========================================================================
# Model Name: models/gemma-3-12b-it,
#  Description:
# ===========================================================================
# ===========================================================================
# Model Name: models/gemma-3-27b-it,
#  Description:
# ===========================================================================
# ===========================================================================
# Model Name: models/gemma-3n-e4b-it,
#  Description:
# ===========================================================================
# ===========================================================================
# Model Name: models/embedding-001,
#  Description: Obtain a distributed representation of a text.
# ===========================================================================
# ===========================================================================
# Model Name: models/text-embedding-004,
#  Description: Obtain a distributed representation of a text.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-embedding-exp-03-07,
#  Description: Obtain a distributed representation of a text.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-embedding-exp,
#  Description: Obtain a distributed representation of a text.
# ===========================================================================
# ===========================================================================
# Model Name: models/aqa,
#  Description: Model trained to return answers to questions that are grounded in provided sources, along with estimating answerable probability.
# ===========================================================================
# ===========================================================================
# Model Name: models/imagen-3.0-generate-002,
#  Description: Vertex served Imagen 3.0 002 model
# ===========================================================================
# ===========================================================================
# Model Name: models/veo-2.0-generate-001,
#  Description: Vertex served Veo 2 model. Access to this model requires billing to be enabled on the associated Google Cloud Platform account. Please visit https://console.cloud.google.com/billing to enable it.
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-preview-native-audio-dialog,
#  Description: Gemini 2.5 Flash Preview Native Audio Dialog
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-preview-native-audio-dialog-rai-v3,
#  Description: Gemini 2.5 Flash Preview Native Audio Dialog RAI v3
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.5-flash-exp-native-audio-thinking-dialog,
#  Description: Gemini 2.5 Flash Exp Native Audio Thinking Dialog
# ===========================================================================
# ===========================================================================
# Model Name: models/gemini-2.0-flash-live-001,
#  Description: Gemini 2.0 Flash 001
# ===========================================================================

# %%
# Initialize the model
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
prompt = "What is universe"

# %%
model.generate_content(prompt).text
# Out:
# 'The Universe is, in its most fundamental sense, **everything that exists**.\n\nIt encompasses:\n\n1.  **All of space and time:** From the smallest subatomic particles to the largest superclusters of galaxies, and the very fabric of time itself.\n2.  **All matter and energy:** This includes everything we can see (normal matter like stars, planets, gas, dust), as well as the mysterious components like dark matter and dark energy, which are believed to make up most of the universe\'s mass and energy.\n3.  **All the laws and constants of physics:** The fundamental rules that govern how everything interacts, such as gravity, electromagnetism, and the strong and weak nuclear forces.\n\nHere\'s a breakdown of its key aspects:\n\n*   **Vastness:** The Universe is mind-bogglingly immense. Our observable universe alone has a diameter of about 93 billion light-years.\n*   **Age:** Current scientific consensus based on the Big Bang theory estimates the Universe to be approximately 13.8 billion years old.\n*   **Origin:** The prevailing cosmological model is the **Big Bang theory**, which describes how the Universe began as an extremely hot, dense point and has been expanding and cooling ever since.\n*   **Evolution:** As the Universe expanded and cooled, fundamental particles formed, then atoms, which eventually clumped together under gravity to form stars, galaxies, galaxy clusters, and the large-scale structures we observe today.\n*   **Composition:**\n    *   **Normal (Baryonic) Matter (~5%):** The stuff we are made of – stars, planets, gas, dust.\n    *   **Dark Matter (~27%):** A mysterious form of matter that does not interact with light or other electromagnetic radiation, but its gravitational effects are observed on galaxies and clusters.\n    *   **Dark Energy (~68%):** An even more mysterious force or energy inherent to space itself, responsible for the accelerating expansion of the Universe.\n*   **Expansion:** The Universe is not static; it is expanding, meaning that the space between galaxies is continually stretching. This expansion is currently accelerating due to dark energy.\n*   **Observable vs. Total Universe:** We can only *observe* a portion of the Universe because light from more distant regions hasn\'t had enough time to reach us since the Big Bang. The total Universe could be much larger than the observable part, or even infinite.\n*   **Fate:** The ultimate fate of the Universe is still a subject of ongoing research, depending on the properties of dark energy. Possible scenarios include the "Big Freeze" (eternal expansion and cooling), the "Big Rip" (expansion tears everything apart), or the "Big Crunch" (collapse back on itself).\n\nIn essence, the Universe is the grand stage for all existence, constantly evolving and still holding countless mysteries for science to uncover.'

# %% [markdown]
# # STRUCTURE CODE

# %%
# Function to generate content
def generate_content(prompt):
    response = model.generate_content(prompt)
    return response.text

# %%
prompt = input ("How may I help you Today.....")
content = generate_content(prompt)

print("\n\n=============================================\n",content)
# Out:
# How may I help you Today..... What is ML?
# =============================================
#  **Machine Learning (ML)** is a subfield of Artificial Intelligence (AI) that focuses on enabling computer systems to **learn from data** without being explicitly programmed for every possible scenario.
#
# Think of it this way:
#
# *   **Traditional Programming:** You write specific, step-by-step instructions for the computer to follow. If you want it to identify a cat, you'd have to write rules like "If it has pointed ears AND whiskers AND a tail, then it's a cat." This becomes incredibly difficult and rigid for complex tasks.
# *   **Machine Learning:** Instead of giving the computer explicit rules, you give it **lots of examples** (data) of cats and non-cats. The ML algorithm then analyzes these examples, identifies patterns and relationships on its own, and *learns* how to distinguish a cat from other animals. Once it has learned, it can apply that knowledge to new, unseen images.
#
# **Key Concepts of ML:**
#
# 1.  **Learning from Data:** ML algorithms are fed large datasets. This data is their "experience."
# 2.  **Pattern Recognition:** The algorithms look for hidden patterns, correlations, and structures within the data.
# 3.  **Building a Model:** Based on the patterns it finds, the algorithm creates a "model." This model is essentially a mathematical representation or set of rules that encapsulate the learned knowledge.
# 4.  **Prediction/Decision Making:** Once the model is trained, it can be used to make predictions, classifications, or decisions on new, unseen data.
# 5.  **Iteration and Improvement:** ML models often improve their performance as they are exposed to more data or as their parameters are fine-tuned.
#
# **Why is ML so powerful?**
#
# *   **Automation of Complex Tasks:** It can automate tasks that are too complex or nuanced for traditional rule-based programming (e.g., recognizing faces, understanding natural language).
# *   **Adaptability:** It can adapt to new data and changing environments without requiring human programmers to constantly rewrite code.
# *   **Discovery:** It can uncover insights and patterns in vast amounts of data that humans might miss.
#
# **Common Applications of ML:**
#
# *   **Recommendation Systems:** (Netflix, Amazon, YouTube suggesting what you might like next)
# *   **Spam Detection:** (Filtering unwanted emails)
# *   **Image and Facial Recognition:** (Tagging friends in photos, unlocking your phone)
# *   **Natural Language Processing (NLP):** (Voice assistants like Siri/Alexa, language translation, sentiment analysis)
# *   **Fraud Detection:** (Identifying suspicious financial transactions)
# *   **Medical Diagnosis:** (Helping doctors identify diseases from scans or patient data)
# *   **Self-Driving Cars:** (Perceiving the environment, making driving decisions)
# *   **Predictive Analytics:** (Forecasting sales, predicting equipment failure)
#
# In essence, Machine Learning is about giving computers the ability to learn and improve from experience, much like humans do, making them incredibly versatile and powerful tools for solving a wide range of real-world problems.
